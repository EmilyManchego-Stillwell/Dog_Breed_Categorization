# %%
import pandas as pd
import os
import re
from sqlalchemy import create_engine
import json

# %% [markdown]
# ## Data Loading
#
# I need to load the akc data csv as a data frame, and then also build a list of dog breeds that we have in our categories in order to match the breeds we have in our project with the breeds y

# %%
akc_df = pd.read_csv("../../Dog_Breed_Files/Data/akc-data-latest.csv")

file_breeds = [breed.strip() for breed in akc_df["Unnamed: 0"].to_list()]

# %%
model_breeds = []

for folder_name in os.listdir("../../Dog_Breed_Files/Images/"):
    # each folder name has format of <string>-<breed>, search for first - and take everything
    search = re.search('.{9}-(.*)', folder_name)
    
    # clean each folder name (will replace some dashes we want at the end but will deal with that later)
    label = search.group(1).replace("_", " ")\
        .replace("-", " ")\
        .title()\
        .strip()
    
    model_breeds.append(label)

# %% [markdown]
# ## Data Matching

# %%
breed_match = {}

for breed in model_breeds:
    if breed in file_breeds:
        breed_match[breed] = "match"
    else:
        breed_match[breed] = "no match"

breed_match_df = pd.DataFrame(data=breed_match.values(), index=breed_match.keys(), columns=["match"])

breed_match_df.to_clipboard()

# %%
# after a lot of trying to force things like "bassett" and "bassett hound" to match I ended up building the final name list in excel
name_match_df = pd.read_csv("folder_akc_name_match.csv")

# %% [markdown]
# ## Building SQLite File

# %%
matches_df = name_match_df[name_match_df["AKC_Match"] != "none"]

# %%
final_df = pd.merge(left=matches_df, right=akc_df, left_on="AKC_Match", right_on="Unnamed: 0").set_index("folder_name")

final_df.head()
# Out:
#             cleaned_folder_name  AKC_Match Unnamed: 0  \
# folder_name
# Chihuahua             Chihuahua  Chihuahua  Chihuahua
# Maltese_dog         Maltese Dog    Maltese    Maltese
# Pekinese               Pekinese  Pekingese  Pekingese
# Shih-Tzu               Shih Tzu   Shih Tzu   Shih Tzu
# papillon               Papillon   Papillon   Papillon
#
#                                                    description  \
# folder_name
# Chihuahua    The Chihuahua is a balanced, graceful dog of t...
# Maltese_dog  Maltese are affectionate toy dogs weighing les...
# Pekinese     Pekingese are compact, stocky toy dogs weighin...
# Shih-Tzu     Shih Tzu (pronounced in the West “sheed-zoo” o...
# papillon     A tiny dog, measuring 8 to 11 inches at the sh...
#
#                                       temperament popularity  min_height  \
# folder_name
# Chihuahua               Charming, Graceful, Sassy         33       12.70
# Maltese_dog             Gentle, Playful, Charming         37       17.78
# Pekinese     Affectionate, Loyal, Regal in Manner         92       15.24
# Shih-Tzu          Affectionate, Playful, Outgoing         20       22.86
# papillon                   Friendly, Alert, Happy         54       20.32
#
#              max_height  min_weight  max_weight  ...  \
# folder_name                                      ...
# Chihuahua         20.32    2.721554    2.721554  ...
# Maltese_dog       22.86    3.175147    3.175147  ...
# Pekinese          22.86    6.350293    6.350293  ...
# Shih-Tzu          26.67    4.082331    7.257478  ...
# papillon          27.94    2.267962    4.535924  ...
#
#              grooming_frequency_value  grooming_frequency_category  \
# folder_name
# Chihuahua                         0.2        Occasional Bath/Brush
# Maltese_dog                       0.8               Daily Brushing
# Pekinese                          0.6    2-3 Times a Week Brushing
# Shih-Tzu                          0.8               Daily Brushing
# papillon                          0.4              Weekly Brushing
#
#             shedding_value  shedding_category energy_level_value  \
# folder_name
# Chihuahua              0.4         Occasional                0.6
# Maltese_dog            0.2         Infrequent                0.6
# Pekinese               0.6           Seasonal                0.4
# Shih-Tzu               0.2         Infrequent                0.6
# papillon               0.6           Seasonal                0.6
#
#              energy_level_category trainability_value  trainability_category  \
# folder_name
# Chihuahua         Regular Exercise                0.4            Independent
# Maltese_dog       Regular Exercise                0.6              Agreeable
# Pekinese                      Calm                0.2        May be Stubborn
# Shih-Tzu          Regular Exercise                0.6              Agreeable
# papillon          Regular Exercise                1.0        Eager to Please
#
#             demeanor_value        demeanor_category
# folder_name
# Chihuahua              0.6         Alert/Responsive
# Maltese_dog            1.0                 Outgoing
# Pekinese               0.4  Reserved with Strangers
# Shih-Tzu               0.8                 Friendly
# papillon               1.0                 Outgoing
#
# [5 rows x 23 columns]

# %%
final_df.to_json("akc_data.json")

# %%
#create engine
engine = create_engine("sqlite:///akc_data.sqlite")

# send to sqlite
final_df.to_sql(name = 'akc_breed_data', con = engine, if_exists='replace', index_label="folder_name")
